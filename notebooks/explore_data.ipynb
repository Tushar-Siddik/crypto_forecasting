# %% [markdown]
# ### Make your src folder importable

# %%
import sys
from pathlib import Path

project_root = Path.cwd().parent
sys.path.append(str(project_root))

# This allows:
# from src.data.data_loader import CryptoDataLoader
# This is the correct approach for notebooks

# %load_ext autoreload
# %autoreload 2

# %%
from src.data.data_loader import CryptoDataLoader

# %% [markdown]
# Create loader

# %%
loader = CryptoDataLoader(data_dir="data/raw")

# %% [markdown]
# Fetch crypto data interactively

# %%
df = loader.fetch_crypto_data(
    ticker="BTC-USD",
    start_date="2025-01-01",
    end_date="2026-01-01"
)

# date fromat: 2022-12-31
# Out:
# Data saved to data/raw\BTC-USD_2025-01-01_2026-01-01.csv

# %%
df.head()
# Out:
#                                    Open          High           Low  \
# Date
# 2025-01-01 00:00:00+00:00  93425.101562  94929.867188  92788.125000
# 2025-01-02 00:00:00+00:00  94416.289062  97739.820312  94201.570312
# 2025-01-03 00:00:00+00:00  96881.726562  98956.914062  96034.617188
# 2025-01-04 00:00:00+00:00  98106.992188  98734.429688  97562.976562
# 2025-01-05 00:00:00+00:00  98233.906250  98813.304688  97291.765625
#
#                                   Close       Volume  Dividends  Stock Splits
# Date
# 2025-01-01 00:00:00+00:00  94419.757812  24519888919        0.0           0.0
# 2025-01-02 00:00:00+00:00  96886.875000  46009564411        0.0           0.0
# 2025-01-03 00:00:00+00:00  98107.429688  35611391163        0.0           0.0
# 2025-01-04 00:00:00+00:00  98236.226562  22342608078        0.0           0.0
# 2025-01-05 00:00:00+00:00  98314.960938  20525254825        0.0           0.0

# %% [markdown]
# Visualize data

# %%
import matplotlib.pyplot as plt

df["Close"].plot(figsize=(12,5), title="BTC Closing Price")
plt.show()

# %% [markdown]
# Load previously saved data

# %%
df_saved = loader.load_saved_data(
    ticker="BTC-USD",
    start_date="2024-01-01",
    end_date="2025-01-01"
)

df_saved.tail()
# Out:
#                                    Open          High           Low  \
# Date
# 2024-12-27 00:00:00+00:00  95704.976562  97294.843750  93310.742188
# 2024-12-28 00:00:00+00:00  94160.187500  95525.898438  94014.289062
# 2024-12-29 00:00:00+00:00  95174.054688  95174.875000  92881.789062
# 2024-12-30 00:00:00+00:00  93527.195312  94903.320312  91317.132812
# 2024-12-31 00:00:00+00:00  92643.250000  96090.601562  91914.031250
#
#                                   Close       Volume  Dividends  Stock Splits
# Date
# 2024-12-27 00:00:00+00:00  94164.859375  52419934565        0.0           0.0
# 2024-12-28 00:00:00+00:00  95163.929688  24107436185        0.0           0.0
# 2024-12-29 00:00:00+00:00  93530.226562  29635885267        0.0           0.0
# 2024-12-30 00:00:00+00:00  92643.210938  56188003691        0.0           0.0
# 2024-12-31 00:00:00+00:00  93429.203125  43625106843        0.0           0.0

# %% [markdown]
# Use “latest data” interactively

# %%
latest_df = loader.get_latest_data("ETH-USD", days=180)
latest_df.tail()
# Out:
# Data saved to data/raw\ETH-USD_2025-07-18_2026-01-14.csv
#                                   Open         High          Low        Close  \
# Date
# 2026-01-09 00:00:00+00:00  3104.334717  3140.709229  3058.096924  3083.047119
# 2026-01-10 00:00:00+00:00  3083.166504  3099.167480  3075.135498  3082.395996
# 2026-01-11 00:00:00+00:00  3082.407471  3141.958008  3080.747803  3118.885254
# 2026-01-12 00:00:00+00:00  3118.828857  3166.219971  3068.072754  3092.325195
# 2026-01-13 00:00:00+00:00  3092.396240  3334.453125  3090.151855  3334.453125
#
#                                 Volume  Dividends  Stock Splits
# Date
# 2026-01-09 00:00:00+00:00  18879517395        0.0           0.0
# 2026-01-10 00:00:00+00:00   6960662969        0.0           0.0
# 2026-01-11 00:00:00+00:00  10497219711        0.0           0.0
# 2026-01-12 00:00:00+00:00  21152711365        0.0           0.0
# 2026-01-13 00:00:00+00:00  25758603264        0.0           0.0
